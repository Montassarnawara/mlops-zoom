# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/codespace/anaconda3/envs/tf-env
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     bzip2-1.0.8                |       h5eee18b_6         262 KB
#     ca-certificates-2025.2.25  |       h06a4308_0         129 KB
#     expat-2.7.1                |       h6a678d5_0         182 KB
#     ld_impl_linux-64-2.40      |       h12ee557_0         710 KB
#     libffi-3.4.4               |       h6a678d5_1         141 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
# ...

# %%
conda activate tf-env
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda init bash
# Out:
# no change     /home/codespace/anaconda3/condabin/conda
# no change     /home/codespace/anaconda3/bin/conda
# no change     /home/codespace/anaconda3/bin/conda-env
# no change     /home/codespace/anaconda3/bin/activate
# no change     /home/codespace/anaconda3/bin/deactivate
# no change     /home/codespace/anaconda3/etc/profile.d/conda.sh
# no change     /home/codespace/anaconda3/etc/fish/conf.d/conda.fish
# no change     /home/codespace/anaconda3/shell/condabin/Conda.psm1
# no change     /home/codespace/anaconda3/shell/condabin/conda-hook.ps1
# no change     /home/codespace/anaconda3/lib/python3.9/site-packages/xontrib/conda.xsh
# no change     /home/codespace/anaconda3/etc/profile.d/conda.csh
# no change     /home/codespace/.bashrc
# No action taken.
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda remove -n tf-env --all -y
# Out:
# Remove all packages in environment /home/codespace/anaconda3/envs/tf-env:
#
#
# ## Package Plan ##
#
#   environment location: /home/codespace/anaconda3/envs/tf-env
#
#
# The following packages will be REMOVED:
#
#   _libgcc_mutex-0.1-main
#   _openmp_mutex-5.1-1_gnu
#   bzip2-1.0.8-h5eee18b_6
#   ca-certificates-2025.2.25-h06a4308_0
#   expat-2.7.1-h6a678d5_0
#   ld_impl_linux-64-2.40-h12ee557_0
#   libffi-3.4.4-h6a678d5_1
#   libgcc-ng-11.2.0-h1234567_1
#   libgomp-11.2.0-h1234567_1
#   libstdcxx-ng-11.2.0-h1234567_1
#   libuuid-1.41.5-h5eee18b_0
#   libxcb-1.17.0-h9b100fa_0
#   ncurses-6.4-h6a678d5_0
#   openssl-3.0.16-h5eee18b_0
#   pip-25.1-pyhc872135_2
#   pthread-stubs-0.3-h0ce48e5_1
#   python-3.10.18-h1a3bd86_0
#   readline-8.2-h5eee18b_0
#   setuptools-78.1.1-py310h06a4308_0
#   sqlite-3.45.3-h5eee18b_0
#   tk-8.6.14-h993c535_1
#   tzdata-2025b-h04d1e81_0
#   wheel-0.45.1-py310h06a4308_0
#   xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau-1.0.12-h9b100fa_0
# ...
